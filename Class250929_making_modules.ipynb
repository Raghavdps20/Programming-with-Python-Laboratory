# %%
import importlib
import mymodule
importlib.reload(mymodule)
# Out:
# <module 'mymodule' from 'C:\\Users\\Raghav Sharma\\Documents\\Jupyter Notebook Saved Files Location\\Projects\\mymodule.py'>

# %%
mymodule.say_hello("Raghav")
# Out:
# Hello, Raghav!

# %%
from mymodule import person1

# %%
print(person1["age"])
# Out:
# 16

# %%
# write a program to add to two number using command line armugents

# %%
import sys

# %%
print(sys.argv)
# Out:
# ['D:\\Users\\RaghavSharma\\anaconda3\\Lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\Raghav Sharma\\AppData\\Roaming\\jupyter\\runtime\\kernel-25876a95-685f-483f-b2ba-4eb2d8470f50.json']

# %%
list1 = {10.45,32,68,55,22,99,43}
max(list1)
# Out:
# 99

# %%
def max(a):
    max = 0
    for num in a:
        if(max<num):
            max = num
    return "max is " + str(max)

# %%
max(list1)
# Out:
# 'max is 99'

# %%
def test():
    def max():
        return "local max here"

    print(max())

# %%
test()
# Out:
# local max here
