# %%
x=10

# %%
if(x>0):
    x=x+1

# %%
print(x)
# Out:
# 11

# %%
age = int(input("Enter the age : "))
if(age>=18):
    print("You can vote")
else:
    print("You cannot vote")
# Out:
# Enter the age :  14
# You cannot vote

# %%
char = input("Press any key")
# Out:
# Press any key a

# %%
if 'A' <= char <= 'Z' or 'a' <= char <= 'z':
    print("Its a alphabet")
# Out:
# Its a alphabet

# %%
age = int(input("Enter the age : "))
if(age>=18):
    print("You can vote")
else:
    print("You cannot vote for another", 18-age, "years")
# Out:
# Enter the age :  13
# You cannot vote for another 5 years

# %%
ch = input("Enter a character")

if(ch.islower()):
    print(ch.upper())
elif(ch.isupper()):
    print(ch.lower())

ch.
# Out:
# Enter a character A
# a
