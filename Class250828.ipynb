# %%
10+7
# Out:
# 17

# %%
50+40-35
# Out:
# 55

# %%
12*10
# Out:
# 120

# %%
96/12
# Out:
# 8.0

# %%
(-30*4) + 500
# Out:
# 380

# %%
1/3
# Out:
# 0.3333333333333333

# %%
f"Value of 1/3 = {1/3:.2f}"
# Out:
# 'Value of 1/3 = 0.33'

# %%
a=13

# %%
b=6

# %%
c=a+b

# %%
print("Sum = , c")
# Out:
# Sum = , c

# %%
print(c)
# Out:
# 19

# %%
d = a - b

# %%
print(d)
# Out:
# 7

# %%
print("Sum = ", c)
# Out:
# Sum =  19

# %%
e = a*b

# %%
print(e)
# Out:
# 78

# %%
a=7

# %%
b=2

# %%
print(a/b)
# Out:
# 3.5

# %%
print(a//b)
# Out:
# 3

# %%
print(-a//b)
# Out:
# -4

# %%
print(10**-1)
# Out:
# 0.1

# %%
print(2**-1)
# Out:
# 0.5

# %%
print(7**0)
# Out:
# 1

# %%
print(7%2)
# Out:
# 1

# %%
x=3
y=2
print(x==y)
# Out:
# False

# %%
x>y
# Out:
# True

# %%
x<y
# Out:
# False

# %%
x!=y
# Out:
# True

# %%
x>=y
# Out:
# True

# %%
x<=y
# Out:
# False

# %%
import sys
print(sys.version)
# Out:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]

# %%
a = 10

# %%
a += 10

# %%
a
# Out:
# 20

# %%
a -= 10

# %%
a
# Out:
# 10

# %%
a *= 10

# %%
a
# Out:
# 100

# %%
a %=  7

# %%
a
# Out:
# 2

# %%
a = 9

# %%
a /= 3

# %%
a
# Out:
# 3.0

# %%
print(a)
# Out:
# 3.0

# %%
a,b,c = 10,20,30

# %%
a=2
b=10
print(a<5 and b>9)
# Out:
# True

# %%
a=2
b=10
print(a<5 and b>19)
# Out:
# False

# %%
a=2
b=10
print(a<5 or b>9)
# Out:
# True

# %%
a=2
b=10
print(a<5 or b>19)
# Out:
# True

# %%
is_Allowance = True

# %%
print(not is_Allowance)
# Out:
# False
