# %%
print("Good + Morning")
# Out:
# Good + Morning

# %%
print("python" + "Technology")
# Out:
# pythonTechnology

# %%
# print("python" + 3.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print("python" + 3.5)
#
# TypeError: can only concatenate str (not "float") to str

# %%
print("python" + "3.5")
# Out:
# python3.5

# %%
print("12" + "34")
# Out:
# 1234

# %%
print("Good" * 5)
# Out:
# GoodGoodGoodGoodGood

# %%
print(5 * "Good")
# Out:
# GoodGoodGoodGoodGood

# %%
# print("Good" * "5")

# %%
# print("Good" * 5.0)

# %%
str = "python is Easy!!!"

# %%
print(str)
# Out:
# python is Easy!!!

# %%
print(str[0])
# Out:
# p

# %%
print(str[3:9])
# Out:
# hon is

# %%
print(str[4:])
# Out:
# on is Easy!!!

# %%
print(str[-1])
# Out:
# !

# %%
print(str[:5])
# Out:
# pytho

# %%
print("What's your name?")
# Out:
# What's your name?

# %%
# print('What's you name?')

# %%
print('''What's your name
?''')
# Out:
# What's your name
# ?

# %%
print('What\'s your name?')
# Out:
# What's your name?

# %%
# print("The boy replies, "My name is Aaditya."")

# %%
print("The boy replies, \"My name is Aaditya.\"")
# Out:
# The boy replies, "My name is Aaditya."

# %%
print("The boy replies, \nMy name is Aaditya.")
# Out:
# The boy replies,
# My name is Aaditya.

# %%
print("The boy replies, \tMy name is Aaditya.")
# Out:
# The boy replies, 	My name is Aaditya.

# %%
print("The boy replies," \
" My name is Aaditya.")
# Out:
# The boy replies, My name is Aaditya.

# %%
print("\\")
# Out:
# \

# %%
print("\'")
# Out:
# '

# %%
print("\"")
# Out:
# "

# %%
print("Hello\n World")
# Out:
# Hello
#  World

# %%
print("Hello\t World")
# Out:
# Hello	 World

# %%
print("\056")
# Out:
# .

# %%
print("\x2E")
# Out:
# .

# %%
print("\x87")
# Out:
# 

# %%
# 11011 -> decimal
print(int("11011", 2))
# Out:
# 27

# %%
# 51 -> octal
print(oct(51))
# Out:
# 0o63

# %%
# 360 octal -> decimal
decimal_num = int("360", 8)  # interpret "360" as octal
print(decimal_num)  # 240
# Out:
# 240

# %%
# 51 -> hexadecmal
print(hex(51))
# Out:
# 0x33

# %%
# 33 hex -> decimal
decimal_num = int("33", 16)
print(decimal_num)  # 51
# Out:
# 51

# %%
x=10
y=4
print(x&y)
# Out:
# 0

# %%
print(x|y)
# Out:
# 14

# %%
print(~x,~y)
# Out:
# -11 -5

# %%
print(x^y)
# Out:
# 14

# %%
print(x>>2)
# Out:
# 2

# %%
print(x<<3)
# Out:
# 80

# %%
x = [1,2]
y = [1,2]
print("x is y" , x is y)
# Out:
# x is y False

# %%
z = x

# %%
print(x is z)
# Out:
# True

# %%
x1 = 5
y1 = 5
x2 = 'HELLO'
y2 = 'HELLO'
x3 = [1,2,3]
y3 = [1,2,3]
print(x1 is y1)
print(x2 is y2)
print(x3 is y3)
# Out:
# True
# True
# False

# %%
message = 'HELLO WORLD'

# %%
dict = {
    1 : 'a',
    2 : 'b',
}

# %%
dict[1]
# Out:
# 'a'

# %%
print("H" in message)
# Out:
# True

# %%
print("HELLO" in message)
# Out:
# True

# %%
print("hello" in message)
# Out:
# False

# %%
print("hello" not in message)
# Out:
# True

# %%
print(1 in dict)
# Out:
# True

# %%
print('a' in dict)
# Out:
# False

# %%
a,b = 10,20

# %%
min = a if a<b else b

# %%
print(min)
# Out:
# 10

# %%
x = 0.5
result = "positive" if x>0 else "negative"
print(result)
# Out:
# positive

# %%
expr = 10 + 20 * 30
print(expr)
# Out:
# 610

# %%
(40+20)*30/10
# Out:
# 180.0

# %%
40+(20*30)/10
# Out:
# 100.0

# %%
False == False or True
# Out:
# True

# %%
 False == (False or True)
# Out:
# False

# %%
print(100/10*10)
# Out:
# 100.0
